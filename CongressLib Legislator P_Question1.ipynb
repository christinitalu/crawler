# %%
from selenium import webdriver
import re
import time
import random
import pandas as pd

# %%
#建立一個dataframe，及欄位名稱"title","category","topic","keywords"
df=pd.DataFrame(columns=["title","category","topic","keywords"])

#開起chrome瀏覽器
driver = webdriver.Chrome('./chromedriver')
driver.implicitly_wait(60)
#開起立法院圖書館委員問政專輯頁面,並點選『立法菁英』
driver.get('https://lis.ly.gov.tw/lylegismc/lylegismemkmout?@@0.6259989951044278')
driver.find_element_by_xpath("""//*[@id="Map"]/area[1]""").click()


#選到第七屆
driver.find_element_by_link_text("7").click()

#點選立法委員，會開啟新頁面，並將操控瀏覽器轉換至新頁面操控
legislator="余天"

driver.find_element_by_link_text(legislator).click()
driver.switch_to_window(driver.window_handles[1])
#點選問政成果
driver.find_element_by_xpath("""//*[@id="menu02"]""").click()
#點選委員質詢
driver.find_element_by_xpath("""//*[@id="pop02"]/a""").click()
#點選專案質詢
driver.find_element_by_link_text("專案質詢").click()

##抓出共幾筆專案質詢x,並將x轉成int
for i in range(0,len(driver.find_elements_by_class_name("p_tab"))):
    x=driver.find_elements_by_class_name("p_tab")[i].text
    match=re.match("專案質詢", x)
    if match :
        x=re.sub("專案質詢\\n\[",'',x)
        x=int(re.sub('\]','',x))

#點選序號１
driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr[3]/td[2]/table/tbody/tr[5]/td/table/tbody/tr/td/table/tbody/tr[2]/td[3]/a""").click()


#開始迭代，從１到ｘ次(x加1不執行)
for i in range(1,x+1):
    if i == 1 :
        try:
            title=driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[2]/td/table/tbody/tr[4]/td[2]""").text
            category= driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[2]/td/table/tbody/tr[12]/td[2]""").text
            topic=driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[2]/td/table/tbody/tr[13]/td[2]""").text
            keywords=driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[2]/td/table/tbody/tr[14]/td[2]""").text
#             #title取前10個字
#             title=title[0:10]
            df.loc[i] = [title,category,topic,keywords]
            print(i, " 案由 :",title[0:10],"...")

            #選取下一筆,只有轉跳到第二筆用此Xpath
            driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[1]/td/table/tbody/tr/td[2]/input[2]""").click()
        except:
                df.loc[i] = [title,'0','0','0']
                driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[1]/td/table/tbody/tr/td[2]/input[2]""").click()
    
    
    if i >1 :
        if i==x:
            title=driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[2]/td/table/tbody/tr[4]/td[2]""").text
            category= driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[2]/td/table/tbody/tr[12]/td[2]""").text
            topic=driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[2]/td/table/tbody/tr[13]/td[2]""").text
            keywords=driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[2]/td/table/tbody/tr[14]/td[2]""").text
#             #title取前10個字
#             title=title[0:10]
            df.loc[i] = [title,category,topic,keywords]
            print(i," 案由 :",title[0:10],"...")
        else:
            try:
                title=driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[2]/td/table/tbody/tr[4]/td[2]""").text
                category= driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[2]/td/table/tbody/tr[12]/td[2]""").text
                topic=driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[2]/td/table/tbody/tr[13]/td[2]""").text
                keywords=driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[2]/td/table/tbody/tr[14]/td[2]""").text
#                 #title取前10個字
#                 title=title[0:10]
                df.loc[i] = [title,category,topic,keywords]
                print(i," 案由 :",title[0:10],"...")
        #         print("1.類別：",category)
        #         print("2.主題：",topic)
        #         print("3.關鍵字 : ",keywords )

    #     #隨機停頓模擬人的行為
    #             time.sleep(random.uniform(0, 2))

                #轉跳到第三筆及之後都使用此Xpath
                driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[1]/td/table/tbody/tr/td[2]/input[3]""").click()
            except:
                df.loc[i] = [title,'0','0','0']
                driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[1]/td/table/tbody/tr/td[2]/input[3]""").click()
print(df)
df.to_excel(legislator+".xls")
driver.close()
driver.switch_to_window(driver.window_handles[0])
driver.quit()
# Out:
# /Users/apple/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:19: DeprecationWarning: use driver.switch_to.window instead
# 1  案由 : 針對新北市幼童遭到虐 ...
# 2  案由 : 針對隧道照明攸關無論 ...
# 3  案由 : 針對國道一號南部都會 ...
# 4  案由 : 針對機場聯外捷運系統 ...
# 5  案由 : 針對有線電視系統、衛 ...
# 6  案由 : 針對我國今（98）年 ...
# 7  案由 : 針對政府積極推動文化 ...
# 8  案由 : 針對台灣有線電視系統 ...
# 9  案由 : 針對中國政府任意毆打 ...
# 10  案由 : 針對現行電影、電視新 ...
# 11  案由 : 針對台灣與中國可能進 ...
# 12  案由 : 針對政府推動「棒球振 ...
# 13  案由 : 針對日前莫拉克颱風重 ...
# 14  案由 : 針對因為莫拉克颱風風 ...
# 15  案由 : 針對國內少子化問題一 ...
# 16  案由 : 針對國內慢慢進入高齡 ...
# 17  案由 : 針對台灣實施全民健保 ...
# 18  案由 : 針對消保會就37家游 ...
# 19  案由 : 針對政府為推動社區總 ...
# 20  案由 : 針對行政院為刺激經濟 ...
# 21  案由 : 針對行政院全力推動文 ...
# 22  案由 : 針對四家無線電視台有 ...
#                                                 title  \
# 1   針對新北市幼童遭到虐殺，是文明社會必須共同承擔的羞恥，為防止類似事件一再發生，實應建立起一預...
# 2   針對隧道照明攸關無論全體用路人的安全，但目前部分隧道照明經實際勘查結果，並未符合國家CNS及...
# 3   針對國道一號南部都會區瀝青混凝土鋪面坑洞嚴重，交通部台灣區國道高速公路局南區工程處委託財團法...
# 4   針對機場聯外捷運系統通車營運後，三重站將不停靠直達班車、也不辦理預辦登機服務，此一規劃方向不...
# 5   針對有線電視系統、衛星電視等媒體亂象叢生，政府卻管理無章、束手無策，以致產生劣幣驅逐良幣情形...
# 6   針對我國今（98）年經濟成長率為負4.04%，國民所得僅16,280美元，8月失業率高達6....
# 7   針對政府積極推動文化創意產業，主管的文建會、新聞局明年度均大幅增編預算，除了協助產業全面發展...
# 8   針對台灣有線電視系統遭外資、財團高度壟斷，恐造成觀眾消費權益受損，政府應更積極要求有線系統經...
# 9   針對中國政府任意毆打、拘留採訪媒體記者，漠視媒體採訪公眾事務權利，嚴正呼籲政府應考量中國是否...
# 10  針對現行電影、電視新聞、資訊、娛樂等節目有關置入行銷相關法規、尺度雜亂無章，不僅有誤導觀眾之...
# 11  針對台灣與中國可能進行的兩岸經濟合作架構協議（ECFA）協商一案，有關文化創意產業部分，強烈...
# 12  針對政府推動「棒球振興計畫」，觀其內容未能就國人體育運動發展做一整體性的研究、規劃，而僅做出...
# 13  針對日前莫拉克颱風重創南台灣，而國內災損學校至少在346所、災損總金額在7700萬元以上，其...
# 14  針對因為莫拉克颱風風災由美國提供外援物資，該物資竟經歷在空軍台南基地卸載、聯勤司令部運送、陸...
# 15  針對國內少子化問題一年比一年嚴重，造成國內大學招不到學生，如今年明道、大葉、南華、佛光、玄奘...
# 16  針對國內慢慢進入高齡化的情況，政府除應考量質量兼濟的新人口政策之外，如何提升老人的健康素質與...
# 17  針對台灣實施全民健保以來，達到全民皆納保、資源耗用少、民眾健康好的三項成效。但是除了達到以上...
# 18  針對消保會就37家游泳業者調查發現，有三成二的業者在救生員、教練人數及救生員、教練證照過期不...
# 19  針對政府為推動社區總體營造特訂定「行政院文化建設委員會社區總體營造獎助須知」，以鼓勵社區居民...
# 20  針對行政院為刺激經濟發展，正全力推動全民減稅、產業補助等措施，然而惟獨對文創產業欠缺具體作為...
# 21  針對行政院全力推動文創產業，且將廣播電視列為十三項重點文創產業之一，顯見文化、藝術已是台灣未...
# 22  針對四家無線電視台有多達三家於晚間黃金時段播出外來戲劇，對台灣文化、教育恐造成長遠傷害，政府...
#
#                      category                 topic            keywords
# 1                          社政                  虐待兒童      幼童 ; 虐殺 ; 安置機制
# 2                          公路             隧道 ; 交通安全          隧道照明 ; 用路人
# 3                          公路             道路 ; 工程品質      瀝青混凝土舖面 ; 偷工減料
# 4                        運輸規劃           大眾捷運 ; 交通建設         三重站 ; 捷運機場線
# 5                        電視廣播           有線電視 ; 電視頻道   劣質頻道 ; 上架費 ; 收視品質
# 6                        經貿其他                  經濟循環               經濟成長率
# 7                        文化政務         文化創意產業 ; 文化資產       文化創意產業 ; 文化資產
# 8                        電視廣播           有線電視 ; 價格壟斷    有線電視系統 ; 外資 ; 財團
# 9                 兩岸政務 ; 文化其他      中國問題 ; 記者 ; 人身自由           中國 ; 記者安全
# 10                電視廣播 ; 文化其他             電視節目 ; 廣告   置入性行銷 ; 竜視節目 ; 法律
# 11  兩岸政務 ; 兩岸文教 ; 經濟政策 ; 文化政務  大陸政策 ; 貿易協定 ; 文化創意產業       ECFA ; 文化創意產業
# 12                         體育                    體育     棒球振興計畫 ; 體育運動發展
# 13                       消防防災                  災害救助               莫拉克颱風
# 14                       消防防災                  災害救助        莫拉克颱風 ; 外援物資
# 15                高等教育 ; 教育政務           教育政策 ; 高等教育    少子化 ; 招生率 ; 高等教育
# 16                         社政                  老人福利     高齡化 ; 老人 ; 健康素質
# 17                         醫政                  醫療政策         醫療資源 ; 藥價黑洞
# 18                         社政             游泳 ; 安全教育    救生員 ; 游泳池 ; 教練證照
# 19                       文化政務                  文化建設         社區居民 ; 公共事務
# 20                       文化政務                文化創意產業         文創產業 ; 文化消費
# 21                       文化政務                文化創意產業  文創產業 ; 資深演藝人員 ; 失業
# 22                       電視廣播                  電視節目        無線電視台 ; 外來戲劇
# /Users/apple/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:94: DeprecationWarning: use driver.switch_to.window instead
