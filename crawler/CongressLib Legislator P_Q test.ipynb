# %%
#下載安裝selenium
import sys
# !{sys.executable} -m pip install selenium
# Out:
# Collecting selenium
#   Downloading https://files.pythonhosted.org/packages/80/d6/4294f0b4bce4de0abf13e17190289f9d0613b0a44e5dd6a7f5ca98459853/selenium-3.141.0-py2.py3-none-any.whl (904kB)
#     100% |████████████████████████████████| 911kB 1.8MB/s ta 0:00:01
# Requirement already satisfied: urllib3 in ./anaconda3/lib/python3.6/site-packages (from selenium) (1.22)
# distributed 1.21.8 requires msgpack, which is not installed.
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0
# You are using pip version 10.0.1, however version 19.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from selenium import webdriver
import re
import time
import random
import pandas as pd

# %%
#建立一個dataframe，及欄位名稱"title","category","topic","keywords"
df=pd.DataFrame(columns=["title","category","topic","keywords"])

#開起chrome瀏覽器
driver = webdriver.Chrome('./chromedriver')
driver.implicitly_wait(60)
#開起立法院圖書館委員問政專輯頁面,並點選『立法菁英』
driver.get('https://lis.ly.gov.tw/lylegismc/lylegismemkmout?@@0.6259989951044278')
driver.find_element_by_xpath("""//*[@id="Map"]/area[1]""").click()


#選到第七屆
driver.find_element_by_link_text("7").click()

#點選立法委員，會開啟新頁面，並將操控瀏覽器轉換至新頁面操控
legislator="丁守中"

driver.find_element_by_link_text(legislator).click()
driver.switch_to_window(driver.window_handles[1])
#點選問政成果
driver.find_element_by_xpath("""//*[@id="menu02"]""").click()
#點選委員質詢
driver.find_element_by_xpath("""//*[@id="pop02"]/a""").click()
#點選專案質詢
driver.find_element_by_link_text("專案質詢").click()

##抓出共幾筆專案質詢x,並將x轉成int
x=driver.find_elements_by_class_name("sum")[2].text
x=re.sub('\[','',x)
x=int(re.sub('\]','',x))

#點選序號１
driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr[3]/td[2]/table/tbody/tr[5]/td/table/tbody/tr/td/table/tbody/tr[2]/td[3]/a""").click()


#開始迭代，從１到ｘ次(x加1不執行)
for i in range(1,x+1):
    if i == 1 :
        try:
            title=driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[2]/td/table/tbody/tr[4]/td[2]""").text
            category= driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[2]/td/table/tbody/tr[12]/td[2]""").text
            topic=driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[2]/td/table/tbody/tr[13]/td[2]""").text
            keywords=driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[2]/td/table/tbody/tr[14]/td[2]""").text
#             #title取前10個字
#             title=title[0:10]
            df.loc[i] = [title,category,topic,keywords]
            print(i, " 案由 :",title[0:10],"...")

            #選取下一筆,只有轉跳到第二筆用此Xpath
            driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[1]/td/table/tbody/tr/td[2]/input[2]""").click()
        except:
                df.loc[i] = [title,'0','0','0']
                driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[1]/td/table/tbody/tr/td[2]/input[2]""").click()
    
    
    if i >1 :
        if i==x:
            title=driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[2]/td/table/tbody/tr[4]/td[2]""").text
            category= driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[2]/td/table/tbody/tr[12]/td[2]""").text
            topic=driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[2]/td/table/tbody/tr[13]/td[2]""").text
            keywords=driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[2]/td/table/tbody/tr[14]/td[2]""").text
#             #title取前10個字
#             title=title[0:10]
            df.loc[i] = [title,category,topic,keywords]
            print(i," 案由 :",title[0:10],"...")
        else:
            try:
                title=driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[2]/td/table/tbody/tr[4]/td[2]""").text
                category= driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[2]/td/table/tbody/tr[12]/td[2]""").text
                topic=driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[2]/td/table/tbody/tr[13]/td[2]""").text
                keywords=driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[2]/td/table/tbody/tr[14]/td[2]""").text
#                 #title取前10個字
#                 title=title[0:10]
                df.loc[i] = [title,category,topic,keywords]
                print(i," 案由 :",title[0:10],"...")
        #         print("1.類別：",category)
        #         print("2.主題：",topic)
        #         print("3.關鍵字 : ",keywords )

    #     #隨機停頓模擬人的行為
    #             time.sleep(random.uniform(0, 2))

                #轉跳到第三筆及之後都使用此Xpath
                driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[1]/td/table/tbody/tr/td[2]/input[3]""").click()
            except:
                df.loc[i] = [title,'0','0','0']
                driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[1]/td/table/tbody/tr/td[2]/input[3]""").click()
print(df)
df.to_excel(legislator+".xls")
driver.close()
driver.switch_to_window(driver.window_handles[0])
driver.quit()
# Out:
# /Users/apple/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:19: DeprecationWarning: use driver.switch_to.window instead
# 1  案由 : 就近日接獲民眾陳情， ...
# 2  案由 : 針對虐童案件頻傳，根 ...
# 3  案由 : 針對近日外籍看護工遭 ...
# 4  案由 : 鑑於近日生乳價格調漲 ...
# 5  案由 : 鑑於韓國已分別與歐盟 ...
# 6  案由 : 鑑於歐洲商會日前（1 ...
# 7  案由 : 鑑於美國與韓國已簽訂 ...
# 8  案由 : 鑑於經濟部投資審議委 ...
# 9  案由 : 鑑於馬總統日前提出「 ...
# 10  案由 : 針對近期國際紙價較前 ...
# 11  案由 : 針對近日接獲民眾陳情 ...
# 12  案由 : 針對近日接受民眾陳情 ...
# 13  案由 : 針對近日接受民眾陳情 ...
# 14  案由 : 針對我國認證制度繁多 ...
# 15  案由 : 針對依財政部海關統計 ...
# 16  案由 : 針對募兵制規劃已久， ...
# 17  案由 : 就經濟部將商業團體分 ...
# 18  案由 : 鑑於馬總統本月（8月 ...
# 19  案由 : 鑑於國內目前每年博士 ...
# 20  案由 : 鑑於教育部與各縣市教 ...
# 21  案由 : 鑑於台大醫院「愛滋器 ...
# 22  案由 : 鑑於「藥價黑洞」問題 ...
# 23  案由 : 鑑於坊間有業者製造、 ...
# 24  案由 : 針就博物館竊案時有所 ...
# 25  案由 : 針就近日台塑六輕再度 ...
# 26  案由 : 針就歐洲先進國家積極 ...
# 27  案由 : 鑑於兩岸直航開放已來 ...
# 28  案由 : 針就建物耗能約佔全球 ...
# 29  案由 : 針就各國近年來為振興 ...
# 30  案由 : 針就接獲民眾陳情，指 ...
# 31  案由 : 鑑於國人深受傳統重男 ...
# 32  案由 : 針就平均每兩天半就會 ...
# 33  案由 : 鑑於兩岸直航開放已來 ...
# 34  案由 : 針就國內航空器鳥擊事 ...
# 35  案由 : 針對部分年老的外籍人 ...
# 36  案由 : 針就「全國性民間體育 ...
# 37  案由 : 針對今年4月陸客來台 ...
# 38  案由 : 針對交通部運輸研究所 ...
# 39  案由 : 針對近日接獲民眾陳情 ...
# 40  案由 : 針對近日接獲民眾反應 ...
# 41  案由 : 針對隨著台灣出生率、 ...
# 42  案由 : 針對我國護理人員不僅 ...
# 43  案由 : 針對產學合作的利益衝 ...
# 44  案由 : 針就近日接獲民眾陳情 ...
# 45  案由 : 針就近日接獲民眾陳情 ...
# 46  案由 : 針對全世界195個國 ...
# 47  案由 : 針對ECFA兩岸經濟 ...
# 48  案由 : 針對我國漁業近年來缺 ...
# 49  案由 : 針對護理人員為醫療團 ...
# 50  案由 : 鑑於近年來騎乘自行車 ...
# 51  案由 : 針對觀光業者陳情國內 ...
# 52  案由 : 針就行政院公平交易委 ...
# 53  案由 : 針就近年來消費市場與 ...
# 54  案由 : 針就為阻止不公平競爭 ...
# 55  案由 : 就國際原油價格不斷飆 ...
# 56  案由 : 針對政府每年進行家庭 ...
# 57  案由 : 就化學物質雙酚A（B ...
# 58  案由 : 就近年來國軍官兵因意 ...
# 59  案由 : 針對民國99年6月兩 ...
# 60  案由 : 針對國內家庭所得差距 ...
# 61  案由 : 針對鳥擊事件一直是國 ...
# 62  案由 : 針就台灣綜合糧食自給 ...
# 63  案由 : 針就台灣老農問題日趨 ...
# 64  案由 : 針就台灣加入WTO後 ...
# 65  案由 : 針就近年來政府大力推 ...
# 66  案由 : 針就政府推動資本市場 ...
# 67  案由 : 針就廣州亞運正如火如 ...
# 68  案由 : 針就接獲民眾陳情，指 ...
# 69  案由 : 針就我國為求經濟發展 ...
# 70  案由 : 針就近日接獲民眾陳情 ...
# 71  案由 : 針就中國大陸日前通過 ...
# 72  案由 : 針就中國大陸於日前審 ...
# 73  案由 : 針就台灣目前糧食自給 ...
# 74  案由 : 針就政府在民國97- ...
# 75  案由 : 針就98年全台自來水 ...
# 76  案由 : 針就國內自行車騎乘者 ...
# 77  案由 : 針對行政院新聞局於2 ...
# 78  案由 : 針就亞洲各國均致力於 ...
# 79  案由 : 針就我國高科技產業在 ...
# 80  案由 : 針就台灣在捐血運動協 ...
# 81  案由 : 針就低工時、打零工等 ...
# 82  案由 : 針對台灣經常舉辦各種 ...
# 83  案由 : 針對民眾來信陳情教育 ...
# 84  案由 : 針就我國對於國外輸入 ...
# 85  案由 : 針就政府目前推動節能 ...
# 86  案由 : 迭來接獲液化石油氣（ ...
# 87  案由 : 針對現行「大陸地區人 ...
# 88  案由 : 針對行政院新聞局於2 ...
# 89  案由 : 針對坊間假藉檢查瓦斯 ...
# 90  案由 : 針對現行國民身分證只 ...
# 91  案由 : 針就我國老年人口成長 ...
# 92  案由 : 針就我國老年人口成長 ...
# 93  案由 : 針就交通部觀光局於日 ...
# 94  案由 : 針就衍生性金融商品與 ...
# 95  案由 : 針就隨著金融市場的蓬 ...
# 96  案由 : 針就經濟部目前正大力 ...
# 97  案由 : 針就過去十年來，區域 ...
# 98  案由 : 針對政府為提升中小學 ...
# 99  案由 : 針對主計處發布國內每 ...
# 100  案由 : 針就內政部統計資料顯 ...
# 101  案由 : 針就八八風災後，國內 ...
# 102  案由 : 針就北二高發生順向坡 ...
# 103  案由 : 針對雲林、彰化自四月 ...
# 104  案由 : 針就接獲知名線上遊戲 ...
# 105  案由 : 針就台灣邁入高齡化社 ...
# 106  案由 : 針對2008年家庭收 ...
# 107  案由 : 針就公司稅後發生虧損 ...
# 108  案由 : 針就自從去年八月兩岸 ...
# 109  案由 : 針就立法院也早已通過 ...
# 110  案由 : 針就國外各先進國家大 ...
# 111  案由 : 針就有史以來最嚴重的 ...
# 112  案由 : 針就兩岸開放包機直航 ...
# 113  案由 : 針對芭樂、柳丁、高麗 ...
# 114  案由 : 針對有機農產品價格較 ...
# 115  案由 : 針對台灣總生育率位居 ...
# 116  案由 : 針對大陸漁船常在台灣 ...
# 117  案由 : 針對目前漁業團體或漁 ...
# 118  案由 : 針對國內會展中心規劃 ...
# 119  案由 : 針就近日來，由於國際 ...
# 120  案由 : 針對海巡署所有近20 ...
# 121  案由 : 針就國內有81.6% ...
# 122  案由 : 針就哥本哈根舉行的2 ...
# 123  案由 : 針就台灣工具機暨零組 ...
# 124  案由 : 針對今年九月份低收入 ...
# 125  案由 : 針對低收入戶戶內家人 ...
# 126  案由 : 針對莫拉克水災已過四 ...
# 127  案由 : 針對目前兩岸氣氛和緩 ...
# 128  案由 : 針對國防部預計民國1 ...
# 129  案由 : 針對「全民健康保險經 ...
# 130  案由 : 針對瓦斯行外送員工邊 ...
# 131  案由 : 針對詐騙案五年間已躍 ...
# 132  案由 : 針對國立故宮博物院對 ...
# 133  案由 : 針對政府積極推廣有機 ...
# 134  案由 : 針對台灣號稱水果王國 ...
# 135  案由 : 針對消基會日前檢測市 ...
# 136  案由 : 針對燁聯取得唐榮鐵工 ...
# 137  案由 : 針對國民年金法將領取 ...
# 138  案由 : 針對目前我國交通部所 ...
# 139  案由 : 針對我國網路線上遊戲 ...
# 140  案由 : 針對《華爾街日報》報 ...
# 141  案由 : 針就我國推動募兵制， ...
# 142  案由 : 針對馬總統於今年四月 ...
# 143  案由 : 針對近十年來台灣地震 ...
# 144  案由 : 針對政府歷年救災特別 ...
# 145  案由 : 針對政府年年編列特別 ...
# 146  案由 : 針對現行健康保險法規 ...
# 147  案由 : 針對我國SBL球星台 ...
# 148  案由 : 針就眾多替代役男陳情 ...
# 149  案由 : 針就溫室效應造成氣候 ...
# 150  案由 : 針對台西客運司機因腦 ...
# 151  案由 : 針對國內美術比賽都是 ...
# 152  案由 : 根據民眾具函陳情，針 ...
# 153  案由 : 針對莫拉克風災重創南 ...
# 154  案由 : 針對莫拉克颱風災區， ...
# 155  案由 : 迭來接獲民眾陳情，針 ...
# 156  案由 : 針就大專畢業生平均待 ...
# 157  案由 : 針就莫拉克颱風重創台 ...
# 158  案由 : 針就近年來大陸漁船及 ...
# 159  案由 : 針就國家通訊傳播委員 ...
# 160  案由 : 針就國內大學生的嚴重 ...
# 161  案由 : 近來接獲許多醫界人士 ...
# 162  案由 : 接獲民眾陳情，表示其 ...
# 163  案由 : 接獲許多健康團體與捐 ...
# 164  案由 : 針就行政院計畫推動的 ...
# 165  案由 : 近日接獲藥師公會全國 ...
# 166  案由 : 針對教育部提出「大學 ...
# 167  案由 : 針就大陸觀光客來台人 ...
# 168  案由 : 針對全球性經濟不景氣 ...
# 169  案由 : 針就三華旅行社「放鴿 ...
# 170  案由 : 針對經濟部提案取消公 ...
# 171  案由 : 鑒於目前國內電信業者 ...
# 172  案由 : 鑒於現行各家行動業者 ...
# 173  案由 : 鑒於現行各家行動業者 ...
# 174  案由 : 針對今年2月份失業率 ...
# 175  案由 : 針對全球性經濟不景氣 ...
# 176  案由 : 針就中華郵政公司郵務 ...
# 177  案由 : 針就我國推動募兵制， ...
# 178  案由 : 針就我國執行工業互惠 ...
# 179  案由 : 針對健保費協會負責協 ...
# 180  案由 : 針對衛生署的回函，表 ...
# 181  案由 : 針對政府為因應高齡化 ...
# 182  案由 : 針對許多無依老人與社 ...
# 183  案由 : 針對政府每逢雨量不足 ...
# 184  案由 : 針就農委會在振興經濟 ...
# 185  案由 : 針就行政院會12日通 ...
# 186  案由 : 針就教育部擬發放教育 ...
# 187  案由 : 針就國內旅遊業者安排 ...
# 188  案由 : 針對溫泉法公布五年多 ...
# 189  案由 : 針對味全嬰幼兒奶粉被 ...
# 190  案由 : 針對大陸地區出現「北 ...
# 191  案由 : 針對美容美髮業者、客 ...
# 192  案由 : 針對台灣平均每三十六 ...
# 193  案由 : 針對中部地區破獲含有 ...
# 194  案由 : 針對扁家四大弊案的審 ...
# 195  案由 : 針對教學醫院與署立醫 ...
# 196  案由 : 針對藥價黑洞造成健保 ...
# 197  案由 : 針就行政院因應金融海 ...
# 198  案由 : 針就選區內最大團體台 ...
# 199  案由 : 針對新聞報導於台北縣 ...
# 200  案由 : 針對市面上許多走私進 ...
# 201  案由 : 針對行政院送審的菸害 ...
# 202  案由 : 針就陸委會副主委趙建 ...
# 203  案由 : 針就經建會發放消費券 ...
# 204  案由 : 針就農委會提出「農村 ...
# 205  案由 : 近日接獲永昕生物醫藥 ...
# 206  案由 : 近日接獲台北市陽明山 ...
# 207  案由 : 鑒於坐落北市中心的台 ...
# 208  案由 : 針就經建會所提出「因 ...
# 209  案由 : 針對國民年金法將領取 ...
# 210  案由 : 針對受國際金融海嘯波 ...
# 211  案由 : 針對台灣經濟不景氣之 ...
# 212  案由 : 針對我國各項特種人員 ...
# 213  案由 : 針對溫泉取用費依據「 ...
# 214  案由 : 針對「國民年金法」立 ...
# 215  案由 : 鑒於台北賓館是依「文 ...
# 216  案由 : 針就世界銀行公布的資 ...
# 217  案由 : 針對行政院為了刺激消 ...
# 218  案由 : 針對巴拿馬籍「Mor ...
# 219  案由 : 近日接獲許多團體、鄉 ...
# 220  案由 : 針對商港法、漁港法分 ...
# 221  案由 : 針就目前政府為減少吸 ...
# 222  案由 : 針就2008年台灣經 ...
# 223  案由 : 針就目前松山機場客運 ...
# 224  案由 : 接獲多所大學學生陳情 ...
# 225  案由 : 針對高高屏地區的民眾 ...
# 226  案由 : 針對市售的保力達B與 ...
# 227  案由 : 針對政府面對群眾遊行 ...
# 228  案由 : 鑑於國內DRAM產業 ...
# 229  案由 : 針就「電子票證發行管 ...
# 230  案由 : 針就全球金融危機餘波 ...
# 231  案由 : 針對政府宣導民眾使用 ...
# 232  案由 : 針就我國執行工業互惠 ...
# 233  案由 : 針就我國執行工業互惠 ...
# 234  案由 : 針對台灣西部沿海廣設 ...
# 235  案由 : 針對國道客運業者與遊 ...
# 236  案由 : 針對黑道伸手進入SB ...
# 237  案由 : 針就早期我國情報工作 ...
# 238  案由 : 針就劉內閣上任至今， ...
# 239  案由 : 針就民進黨執政時期， ...
# 240  案由 : 針就國防部每週固定於 ...
# 241  案由 : 針就推動陸客來台觀光 ...
# 242  案由 : 針就交通部觀光局提出 ...
# 243  案由 : 針對行政院新聞局對國 ...
# 244  案由 : 針就中國大陸海協會副 ...
# 245  案由 : 針就中國海協會會長陳 ...
# 246  案由 : 針就目前行政院開放大 ...
# 247  案由 : 針就日前在台北市著名 ...
# 248  案由 : 針就過去數年國內重大 ...
# 249  案由 : 針就各先進國家因應人 ...
# 250  案由 : 針對美容美髮業播放電 ...
# 251  案由 : 針就行政院農業委員會 ...
# 252  案由 : 針就教育部基於協助弱 ...
# 253  案由 : 針就行政院對非營業特 ...
# 254  案由 : 針就教育部擬實施的「 ...
# 255  案由 : 針就中小學用電長年收 ...
# 256  案由 : 針對台灣海岸線設置了 ...
# 257  案由 : 時常接獲扶輪社社友、 ...
# 258  案由 : 針對國科會所提出的業 ...
# 259  案由 : 針就台灣高鐵推出新的 ...
# 260  案由 : 針就過去數年國內重大 ...
# 261  案由 : 針就國內青少年學童使 ...
# 262  案由 : 鑑於行政院推動節能減 ...
# 263  案由 : 針就我外交部各地域司 ...
# 264  案由 : 針對現行的法規制度， ...
# 265  案由 : 針就行政實施「工作所 ...
# 266  案由 : 針就毒奶危機越演越烈 ...
# 267  案由 : 針就近來爆發的陸軍裝 ...
# 268  案由 : 針就辛樂克颱風造成南 ...
# 269  案由 : 針就役男入營服役日期 ...
# 270  案由 : 針就行政院海岸巡防署 ...
# 271  案由 : 針對澎湖地區醫療資源 ...
# 272  案由 : 針對三鹿公司的毒奶粉 ...
# 273  案由 : 針對台股自五二○以來 ...
# 274  案由 : 針對美國保險鉅子AI ...
# 275  案由 : 針對美商雷曼兄弟公司 ...
# 276  案由 : 針就「商港法」第十八 ...
# 277  案由 : 時常接獲扶輪社社友、 ...
# 278  案由 : 針對健保局對於全民健 ...
# 279  案由 : 針就台北縣警局爆發員 ...
# 280  案由 : 針就辛樂克颱風造成南 ...
# 281  案由 : 針就辛樂克颱風造成全 ...
# 282  案由 : 針對目前嚴重的藥價黑 ...
# 283  案由 : 針對國內業者進口日本 ...
# 284  案由 : 針對眾多艱困的中小企 ...
# 285  案由 : 針就兩岸往來漸趨頻繁 ...
# 286  案由 : 針就滿街林立的飲料店 ...
# 287  案由 : 針就炎熱的暑假已經來 ...
# 288  案由 : 針就自民國84年「家 ...
# 289  案由 : 針對行政院農委會農糧 ...
# 290  案由 : 去（96）年台商替台 ...
# 291  案由 : 針就近年來國內隨著經 ...
# 292  案由 : 針就台灣電力公司為鼓 ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-329-6baad4dc498d> in <module>()
#      68                 title=driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[2]/td/table/tbody/tr[4]/td[2]""").text
# ---> 69                 category= driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[2]/td/table/tbody/tr[12]/td[2]""").text
#      70                 topic=driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[2]/td/table/tbody/tr[13]/td[2]""").text
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py in text(self)
#      75         """The text of the element."""
# ---> 76         return self._execute(Command.GET_ELEMENT_TEXT)['value']
#      77
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      65                                            headers=headers,
# ---> 66                                            **urlopen_kw)
#      67         else:
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/request.py in request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#      86
# ---> 87         return self.urlopen(method, url, **extra_kw)
#      88
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     320         else:
# --> 321             response = conn.urlopen(method, u.request_uri, **kw)
#     322
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#
# ~/anaconda3/lib/python3.6/http/client.py in getresponse(self)
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#
# ~/anaconda3/lib/python3.6/http/client.py in begin(self)
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#
# ~/anaconda3/lib/python3.6/http/client.py in _read_status(self)
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#
# ~/anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# ConnectionRefusedError                    Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      82     if err is not None:
# ---> 83         raise err
#      84
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     356         else:
# --> 357             conn.request(method, url, **httplib_request_kw)
#     358
#
# ~/anaconda3/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# ~/anaconda3/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# ~/anaconda3/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# ~/anaconda3/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# ~/anaconda3/lib/python3.6/http/client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     165     def connect(self):
# --> 166         conn = self._new_conn()
#     167         self._prepare_conn(conn)
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     149             raise NewConnectionError(
# --> 150                 self, "Failed to establish a new connection: %s" % e)
#     151
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x113d51f28>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# <ipython-input-329-6baad4dc498d> in <module>()
#      85             except:
#      86                 df.loc[i] = [title,'0','0','0']
# ---> 87                 driver.find_element_by_xpath("""/html/body/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[1]/td/table/tbody/tr/td[2]/input[3]""").click()
#      88 print(df)
#      89 df.to_excel(legislator+".xls")
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      68             return self.request_encode_body(method, url, fields=fields,
#      69                                             headers=headers,
# ---> 70                                             **urlopen_kw)
#      71
#      72     def request_encode_url(self, method, url, fields=None, headers=None,
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     146         extra_kw.update(urlopen_kw)
#     147
# --> 148         return self.urlopen(method, url, **extra_kw)
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     319             response = conn.urlopen(method, url, **kw)
#     320         else:
# --> 321             response = conn.urlopen(method, u.request_uri, **kw)
#     322
#     323         redirect_location = redirect and response.get_redirect_location()
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     666                                 timeout=timeout, pool_timeout=pool_timeout,
#     667                                 release_conn=release_conn, body_pos=body_pos,
# --> 668                                 **response_kw)
#     669
#     670         def drain_and_release_conn(response):
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     666                                 timeout=timeout, pool_timeout=pool_timeout,
#     667                                 release_conn=release_conn, body_pos=body_pos,
# --> 668                                 **response_kw)
#     669
#     670         def drain_and_release_conn(response):
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     666                                 timeout=timeout, pool_timeout=pool_timeout,
#     667                                 release_conn=release_conn, body_pos=body_pos,
# --> 668                                 **response_kw)
#     669
#     670         def drain_and_release_conn(response):
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#     641
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     386
#     387         if new_retry.is_exhausted():
# --> 388             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     389
#     390         log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='127.0.0.1', port=62384): Max retries exceeded with url: /session/26c105960968f066fcd211694daf9ae7/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x113d51f28>: Failed to establish a new connection: [Errno 61] Connection refused',))

# %%
driver = webdriver.Chrome('./chromedriver')
driver.implicitly_wait(60)
#開起立法院圖書館委員問政專輯頁面,並點選『立法菁英』
driver.get('https://lis.ly.gov.tw/lylegismc/lylegismemkmout?@@0.6259989951044278')
driver.find_element_by_xpath("""//*[@id="Map"]/area[1]""").click()

#選到第七屆
driver.find_element_by_link_text("7").click()

#點選立法委員，會開啟新頁面，並將操控瀏覽器轉換至新頁面操控
legislator="丁守中"

driver.find_element_by_link_text(legislator).click()
driver.switch_to_window(driver.window_handles[1])
#點選問政成果
driver.find_element_by_xpath("""//*[@id="menu02"]""").click()
#點選委員質詢
driver.find_element_by_xpath("""//*[@id="pop02"]/a""").click()
#點選專案質詢
driver.find_element_by_link_text("專案質詢").click()
# Out:
# /Users/apple/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: DeprecationWarning: use driver.switch_to.window instead
